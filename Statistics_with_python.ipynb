# %% [markdown]
# <a href="https://colab.research.google.com/github/nadireus/Statistics-with-Python/blob/main/Statistics_with_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
from scipy.special import perm
from scipy.special import comb
from scipy import stats

# %%
import numpy as np

# %% [markdown]
# ##EXERCISE 1. Answer the following questions by looking at the distribution table or coding with Python.

# %% [markdown]
# 1-A salesperson has found that the probability of a sale on a single contact is approximately .3. If the salesperson contacts 10 prospects, what is the approximate probability of making at least one sale?

# %%
n=10
p=.3
x=1

# %%
stats.binom.pmf(x, n, p) #exactly one sale
# Out:
# 0.12106082100000018

# %% [markdown]
# #at least one sale--> this is P(X≥1)=P(1)+P(2)+P(3)+...+P(10)

# %%
x=1

# %%
1-stats.binom.cdf(x-1,n,p)
# Out:
# 0.9717524751000001

# %% [markdown]
# ##2-Ten coins are tossed simultaneously. Find the probability of getting
#
# ##(i) at least seven heads
#
# ##(ii) exactly seven heads
#
# ##(iii)at most seven heads

# %% [markdown]
# ##at least seven heads--> this is P(X≥7)=P(7)+P(8)+P(9)+P(10)

# %%
n=10
p=.5
x=7

# %%
1-stats.binom.cdf(x-1,n,p)
# Out:
# 0.171875

# %% [markdown]
# ##exactly seven heads

# %%
n=10
p=.5
x=7

# %%
stats.binom.pmf(x, n, p) #exactly seven heads
# Out:
# 0.11718750000000014

# %%
stats.binom.mean(n,p)
# Out:
# 5.0

# %% [markdown]
# ##at most seven heads--> this is P(X≤7)=1−P(X>7)=P(7)+P(8)+P(9)+P(10)

# %%
stats.binom.cdf(x,n,p)
# Out:
# 0.9453125

# %% [markdown]
# #EXERCISE 2. The cycle time for trucks hauling concrete to a highway construction site is uniformly distributed over the interval 50 to 70 minutes. What is the probability that the cycle time exceeds 65 minutes  if it is known that the cycle time exceeds 55 minutes?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
mu=60
sigma=s = np.std(xbar, ddof=1)
x1=55
x2=65

# %%
p55=stats.norm.cdf(x1,mu,sigma)
p65=stats.norm.cdf(x2,mu,sigma)
p55np65=p65-p55
p55np65
# Out:
# 0.406056023605556

# %%
from scipy.integrate import quad

# %% [markdown]
# #EXERCISE 3. The width of bolts of fabric is normally distributed with mean 950 mm (millimeters) and standard deviation 10 mm.

# %% [markdown]
# 1-What is the probability that a randomly chosen bolt has a width of between 947 and 958mm?

# %% [markdown]
# with Python

# %%
mu=950
sigma=10
x1=947
x2=958

# %%
stats.norm.cdf(x2,mu,sigma)-stats.norm.cdf(x1,mu,sigma)
# Out:
# 0.406056023605556

# %% [markdown]
# with statistics
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##2-What is the appropriate value for C such that a randomly chosen bolt has a width less than C with probability .8531?

# %% [markdown]
# with statics

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# with python

# %%
mu=950
sigma=10
q=0.8531

# %%
stats.norm.ppf(q, loc=mu, scale=sigma)
# Out:
# 960.4982190962642

# %% [markdown]
# #EXERCISE 4. Suppose scores on exams in statistics are normally distributed with an unknown population mean and a population standard deviation of 3 points. A random sample of 36 scores is taken and gives a sample mean (sample mean score) of 68. Find a confidence interval estimate for the population mean exam score (the mean score on all exams). Find a 90% confidence interval for the true (population) mean of statistics exam scores.

# %% [markdown]
# ##with python

# %%
# Sample size
n = 36

# Sample mean
xbar = 68

# Sample standard deviation
s = np.std(xbar, ddof=3)

# Confidence level
cl = 0.90
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:234: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
stats.t.interval(0.90, df=n-1, loc=xbar, scale=s/np.sqrt(n))
# Out:
# (nan, nan)

# %%
n = 36
xbar = 68

cl = 0.90
 

sem = s/np.sqrt(n)

# %%
stats.norm.interval(0.90, loc=xbar, scale=sem)
# Out:
# (nan, nan)

# %%
z = stats.norm.ppf(0.90)
z
# Out:
# 1.2815515655446004

# %%
moe = z * sem
moe
# Out:
# nan

# %% [markdown]
# with statics

# %% [markdown]
# ##![image.png](data:image/png;base64,...)

# %% [markdown]
# #EXERCISE 5.  What is the normal body temperature for healthy humans? A random sample of 130 healthy human body temperatures provided by Allen Shoemaker7 yielded 98.25 degrees and standard deviation 0.73 degrees. Give a 99% confidence interval for the average body temperature of healthy people.

# %% [markdown]
# ##with python

# %%
n=130
xbar=98.25
s=0.73
df=n-1

# %%
stats.t.interval(0.99, df=n-1, loc=xbar, scale=s/np.sqrt(n))
# Out:
# (98.74201563335421, 99.0579843666458)

# %% [markdown]
# ##with statistics

# %% [markdown]
# ![IMG_1042[738].jpg](data:image/jpeg;base64,...)
